# %%
import pandas as pd
import os

# (kod jak w Twoim przykładzie)
# Out:
# ✓ Dane wczytane pomyślnie: 8 wierszy, 14 kolumn
# ...
#           RAPORT ANALIZY DANYCH HEART DISEASE
# ...
# Liczba próbek:          8
# Liczba cech:            14
# Brakujące wartości:     6
# Zduplikowane wiersze:   0
# Rozkład target:         {0: 7}
# --- Statystyki opisowe (numeryczne) ---
#               age       sex        cp  trestbps        chol  ...
# count        7.00  7.000000  7.000000      7.00     7.00000  ...
# mean        52.43  0.428571  1.285714    132.14   251.86     ...
# std          9.55  0.534522  1.112697     10.85    58.90     ...
# min         37.00  0.000000  0.000000    120.00   192.00     ...
# 25%         41.50  0.000000  0.500000    120.00   218.50     ...
# 50%         56.00  0.000000  1.000000    130.00   236.00     ...
# 75%         57.00  1.000000  2.500000    140.00   273.50     ...
# max         63.00  1.000000  3.000000    145.00   354.00     ...
# --- Typy danych ---
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# ...
